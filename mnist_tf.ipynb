# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 4s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
plt.imshow(x_train[1], cmap='gray')

# %%
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
plt.imshow(x_train[1], cmap='gray')

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2586 - accuracy: 0.9260
# Epoch 2/3
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1058 - accuracy: 0.9675
# Epoch 3/3
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0728 - accuracy: 0.9772

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
print(val_loss, val_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0972 - accuracy: 0.9696
# 0.09718799591064453 0.9696000218391418

# %%
predictions = model.predict([x_test])
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=(<tf.Tensor 'IteratorGetNext:0' shape=(None, 28, 28) dtype=float32>,). Consider rewriting this model with the Functional API.
# 313/313 [==============================] - 1s 2ms/step

# %%
print(np.argmax(predictions[0]))
# Out:
# 7

# %%
plt.imshow(x_test[0], cmap='gray')
